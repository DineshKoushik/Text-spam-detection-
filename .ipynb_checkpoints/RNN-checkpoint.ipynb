# %% [markdown]
# # Compare NLP Techniques: Build A Basic RNN

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import pandas as pd

X_train = pd.read_csv('X_train.csv')
X_test = pd.read_csv('X_test.csv')
y_train = pd.read_csv('y_train.csv')
y_test = pd.read_csv('y_test.csv')

# %% [markdown]
# ### Prep Data

# %%
# Train the tokenizer and use that tokenizer to convert the sentences to sequences of numbers
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train['clean_text'])
X_train_seq = tokenizer.texts_to_sequences(X_train['clean_text'])
X_test_seq = tokenizer.texts_to_sequences(X_test['clean_text'])

# %%
# Pad the sequences so each sequence is the same length
X_train_seq_padded = pad_sequences(X_train_seq, 50)
X_test_seq_padded = pad_sequences(X_test_seq, 50)

# %% [markdown]
# ### Build And Evaluate RNN

# %%
# Import the tools needed and use our previously defined functions to calculate precision and recall
import keras.backend as K
from keras.layers import Dense, Embedding, LSTM
from keras.models import Sequential

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

# %%
# Construct our basic RNN model framework
model = Sequential()

model.add(Embedding(len(tokenizer.index_word)+1, 32))
model.add(LSTM(32, dropout=0, recurrent_dropout=0))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 32)          265760
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                8320
# _________________________________________________________________
# dense (Dense)                (None, 32)                1056
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 275,169
# Trainable params: 275,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', precision_m, recall_m])

# %%
# Fit the RNN
history = model.fit(X_train_seq_padded, y_train['label'], 
                    batch_size=32, epochs=10,
                    validation_data=(X_test_seq_padded, y_test))
# Out:
# Epoch 1/10
# 140/140 [==============================] - 6s 27ms/step - loss: 0.4128 - accuracy: 0.8714 - precision_m: 0.1995 - recall_m: 0.1826 - val_loss: 0.0744 - val_accuracy: 0.9794 - val_precision_m: 0.9714 - val_recall_m: 0.8168
# Epoch 2/10
# 140/140 [==============================] - 2s 17ms/step - loss: 0.0452 - accuracy: 0.9886 - precision_m: 0.9657 - recall_m: 0.8949 - val_loss: 0.0471 - val_accuracy: 0.9883 - val_precision_m: 0.9524 - val_recall_m: 0.8959
# Epoch 3/10
# 140/140 [==============================] - 2s 17ms/step - loss: 0.0091 - accuracy: 0.9988 - precision_m: 0.9917 - recall_m: 0.9810 - val_loss: 0.0495 - val_accuracy: 0.9901 - val_precision_m: 0.9586 - val_recall_m: 0.9031
# Epoch 4/10
# 140/140 [==============================] - 2s 18ms/step - loss: 0.0028 - accuracy: 0.9994 - precision_m: 0.9999 - recall_m: 0.9956 - val_loss: 0.0561 - val_accuracy: 0.9892 - val_precision_m: 0.9586 - val_recall_m: 0.8959
# Epoch 5/10
# 140/140 [==============================] - 2s 17ms/step - loss: 9.9860e-04 - accuracy: 0.9998 - precision_m: 1.0000 - recall_m: 0.9986 - val_loss: 0.0624 - val_accuracy: 0.9892 - val_precision_m: 0.9586 - val_recall_m: 0.8983
# Epoch 6/10
# 140/140 [==============================] - 2s 17ms/step - loss: 5.2807e-04 - accuracy: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0716 - val_accuracy: 0.9874 - val_precision_m: 0.9586 - val_recall_m: 0.8871
# Epoch 7/10
# 140/140 [==============================] - 3s 19ms/step - loss: 2.2241e-04 - accuracy: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0727 - val_accuracy: 0.9874 - val_precision_m: 0.9586 - val_recall_m: 0.8871
# Epoch 8/10
# 140/140 [==============================] - 3s 24ms/step - loss: 1.5416e-04 - accuracy: 1.0000 - precision_m: 0.9999 - recall_m: 0.9999 - val_loss: 0.0763 - val_accuracy: 0.9874 - val_precision_m: 0.9586 - val_recall_m: 0.8871
# Epoch 9/10
# 140/140 [==============================] - 2s 18ms/step - loss: 1.5073e-04 - accuracy: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0811 - val_accuracy: 0.9874 - val_precision_m: 0.9586 - val_recall_m: 0.8871
# Epoch 10/10
# 140/140 [==============================] - 2s 17ms/step - loss: 6.6614e-05 - accuracy: 1.0000 - precision_m: 0.9996 - recall_m: 0.9996 - val_loss: 0.0797 - val_accuracy: 0.9874 - val_precision_m: 0.9586 - val_recall_m: 0.8871

# %%
# Plot basic evaluation metrics across epochs
import matplotlib.pyplot as plt
# %matplotlib inline

for i in ['accuracy', 'precision_m', 'recall_m']:
    acc = history.history[i]
    val_acc = history.history['val_{}'.format(i)]
    epochs = range(1, len(acc) + 1)

    plt.figure()
    plt.plot(epochs, acc, label='Training Accuracy')
    plt.plot(epochs, val_acc, label='Validation Accuracy')
    plt.title('Results for {}'.format(i))
    plt.legend()
    plt.show()
